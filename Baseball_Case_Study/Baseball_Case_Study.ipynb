# %%
import numpy as np
import pandas as pd

# %%
import seaborn as sns
import matplotlib.pyplot as plt
from sklearn.linear_model import LinearRegression

# %%
# Read Data from CSV File
url = "https://raw.githubusercontent.com/neha-mishra/Evaluation-Projects/main/Baseball_Case_Study/baseball.csv"
df = pd.read_csv(url)

# Adjust index to start from 1 instead of 0
df.index += 1

# %%
# Show top 5 rows of DataFrame
df.head()
# Out:
#     W    R    AB     H   2B  3B   HR   BB    SO   SB   RA   ER   ERA  CG  SHO  \
# 1  95  724  5575  1497  300  42  139  383   973  104  641  601  3.73   2    8
# 2  83  696  5467  1349  277  44  156  439  1264   70  700  653  4.07   2   12
# 3  81  669  5439  1395  303  29  141  533  1157   86  640  584  3.67  11   10
# 4  76  622  5533  1381  260  27  136  404  1231   68  701  643  3.98   7    9
# 5  74  689  5605  1515  289  49  151  455  1259   83  803  746  4.64   7   12
#
#    SV    E
# 1  56   88
# 2  45   86
# 3  38   79
# 4  37  101
# 5  35   86

# %%
# Check DataFrame Shape
df.shape
# Out:
# (30, 17)

# %%
# Get datatypes of all columns
df.dtypes
# Out:
# W        int64
# R        int64
# AB       int64
# H        int64
# 2B       int64
# 3B       int64
# HR       int64
# BB       int64
# SO       int64
# SB       int64
# RA       int64
# ER       int64
# ERA    float64
# CG       int64
# SHO      int64
# SV       int64
# E        int64
# dtype: object

# %%
# Get full info of DataFrame
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 30 entries, 1 to 30
# Data columns (total 17 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   W       30 non-null     int64
#  1   R       30 non-null     int64
#  2   AB      30 non-null     int64
#  3   H       30 non-null     int64
#  4   2B      30 non-null     int64
#  5   3B      30 non-null     int64
#  6   HR      30 non-null     int64
#  7   BB      30 non-null     int64
#  8   SO      30 non-null     int64
#  9   SB      30 non-null     int64
#  10  RA      30 non-null     int64
#  11  ER      30 non-null     int64
#  12  ERA     30 non-null     float64
#  13  CG      30 non-null     int64
#  14  SHO     30 non-null     int64
#  15  SV      30 non-null     int64
#  16  E       30 non-null     int64
# dtypes: float64(1), int64(16)
# memory usage: 4.1 KB

# %%
# Get Summery of DataFrame
df.describe(include='all')
# Out:
#                 W           R           AB            H          2B  \
# count   30.000000   30.000000    30.000000    30.000000   30.000000
# mean    80.966667  688.233333  5516.266667  1403.533333  274.733333
# std     10.453455   58.761754    70.467372    57.140923   18.095405
# min     63.000000  573.000000  5385.000000  1324.000000  236.000000
# 25%     74.000000  651.250000  5464.000000  1363.000000  262.250000
# 50%     81.000000  689.000000  5510.000000  1382.500000  275.500000
# 75%     87.750000  718.250000  5570.000000  1451.500000  288.750000
# max    100.000000  891.000000  5649.000000  1515.000000  308.000000
#
#               3B          HR          BB          SO          SB          RA  \
# count  30.000000   30.000000   30.000000    30.00000   30.000000   30.000000
# mean   31.300000  163.633333  469.100000  1248.20000   83.500000  688.233333
# std    10.452355   31.823309   57.053725   103.75947   22.815225   72.108005
# min    13.000000  100.000000  375.000000   973.00000   44.000000  525.000000
# 25%    23.000000  140.250000  428.250000  1157.50000   69.000000  636.250000
# 50%    31.000000  158.500000  473.000000  1261.50000   83.500000  695.500000
# 75%    39.000000  177.000000  501.250000  1311.50000   96.500000  732.500000
# max    49.000000  232.000000  570.000000  1518.00000  134.000000  844.000000
#
#                ER        ERA         CG        SHO         SV           E
# count   30.000000  30.000000  30.000000  30.000000  30.000000   30.000000
# mean   635.833333   3.956333   3.466667  11.300000  43.066667   94.333333
# std     70.140786   0.454089   2.763473   4.120177   7.869335   13.958889
# min    478.000000   2.940000   0.000000   4.000000  28.000000   75.000000
# 25%    587.250000   3.682500   1.000000   9.000000  37.250000   86.000000
# 50%    644.500000   4.025000   3.000000  12.000000  42.000000   91.000000
# 75%    679.250000   4.220000   5.750000  13.000000  46.750000   96.750000
# max    799.000000   5.040000  11.000000  21.000000  62.000000  126.000000

# %%
# Get DataFrame of rows with missing data
null_data = df[df.isnull().any(axis=1)]
null_data
# Out:
# Empty DataFrame
# Columns: [W, R, AB, H, 2B, 3B, HR, BB, SO, SB, RA, ER, ERA, CG, SHO, SV, E]
# Index: []

# %%
# Check DataFrame for null value
sns.heatmap(df.isnull().sum().to_frame())
# Out:
# <AxesSubplot:>

# %% [markdown]
# # Data Visualization

# %% [markdown]
# Relation between Win and all other columns

# %%
# Win and Run(R)

plt.figure(figsize=(20,5))
plt.subplot(1,3,1)
sns.histplot(x='R',data=df,kde=True)

plt.subplot(1,3,2)
sns.regplot(x='R',y='W',data=df)

plt.subplot(1,3,3)
sns.boxplot(y='R',data=df)

plt.show()

# %%
# Win and At Balls(AB)

plt.figure(figsize=(20,5))
plt.subplot(1,3,1)
sns.histplot(x='AB',data=df,kde=True)

plt.subplot(1,3,2)
sns.regplot(x='AB',y='W',data=df)

plt.subplot(1,3,3)
sns.boxplot(y='AB',data=df)

plt.show()

# %%
# Win and Hits(H)

plt.figure(figsize=(20,5))
plt.subplot(1,3,1)
sns.histplot(x='H',data=df,kde=True)

plt.subplot(1,3,2)
sns.regplot(x='H',y='W',data=df)

plt.subplot(1,3,3)
sns.boxplot(y='H',data=df)

plt.show()

# %%
# Win and Doubles(2B)

plt.figure(figsize=(20,5))
plt.subplot(1,3,1)
sns.histplot(x='2B',data=df,kde=True)

plt.subplot(1,3,2)
sns.regplot(x='2B',y='W',data=df)

plt.subplot(1,3,3)
sns.boxplot(y='2B',data=df)

plt.show()

# %%
# Win and Triples(3B)

plt.figure(figsize=(20,5))
plt.subplot(1,3,1)
sns.histplot(x='3B',data=df,kde=True)

plt.subplot(1,3,2)
sns.regplot(x='3B',y='W',data=df)

plt.subplot(1,3,3)
sns.boxplot(y='3B',data=df)

plt.show()

# %%
# Win and Home Runs(HR)

plt.figure(figsize=(20,5))
plt.subplot(1,3,1)
sns.histplot(x='HR',data=df,kde=True)

plt.subplot(1,3,2)
sns.regplot(x='HR',y='W',data=df)

plt.subplot(1,3,3)
sns.boxplot(y='HR',data=df)

plt.show()

# %%
# Win and Walks(BB)

plt.figure(figsize=(20,5))
plt.subplot(1,3,1)
sns.histplot(x='BB',data=df,kde=True)

plt.subplot(1,3,2)
sns.regplot(x='BB',y='W',data=df)

plt.subplot(1,3,3)
sns.boxplot(y='BB',data=df)

plt.show()

# %%
# Win and Strikeouts(SO)

plt.figure(figsize=(20,5))
plt.subplot(1,3,1)
sns.histplot(x='SO',data=df,kde=True)

plt.subplot(1,3,2)
sns.regplot(x='SO',y='W',data=df)

plt.subplot(1,3,3)
sns.boxplot(y='SO',data=df)

plt.show()

# %%
# Win and Stolen Bases(SB)

plt.figure(figsize=(20,5))
plt.subplot(1,3,1)
sns.histplot(x='SB',data=df,kde=True)

plt.subplot(1,3,2)
sns.regplot(x='SB',y='W',data=df)

plt.subplot(1,3,3)
sns.boxplot(y='SB',data=df)

plt.show()

# %%
# Win and Runs Allowed(RA)

plt.figure(figsize=(20,5))
plt.subplot(1,3,1)
sns.histplot(x='RA',data=df,kde=True)

plt.subplot(1,3,2)
sns.regplot(x='RA',y='W',data=df)

plt.subplot(1,3,3)
sns.boxplot(y='RA',data=df)

plt.show()

# %%
# Win and Earned Runs(ER)

plt.figure(figsize=(20,5))
plt.subplot(1,3,1)
sns.histplot(x='ER',data=df,kde=True)

plt.subplot(1,3,2)
sns.regplot(x='ER',y='W',data=df)

plt.subplot(1,3,3)
sns.boxplot(y='ER',data=df)

plt.show()

# %%
# Win and Earned Run Average(ERA)

plt.figure(figsize=(20,5))
plt.subplot(1,3,1)
sns.histplot(x='ERA',data=df,kde=True)

plt.subplot(1,3,2)
sns.regplot(x='ERA',y='W',data=df)

plt.subplot(1,3,3)
sns.boxplot(y='ERA',data=df)

plt.show()

# %%
# Win and Shutouts(CG)

plt.figure(figsize=(20,5))
plt.subplot(1,3,1)
sns.histplot(x='CG',data=df,kde=True)

plt.subplot(1,3,2)
sns.regplot(x='CG',y='W',data=df)

plt.subplot(1,3,3)
sns.boxplot(y='CG',data=df)

plt.show()

# %%
# Win and Saves(SV)

plt.figure(figsize=(20,5))
plt.subplot(1,3,1)
sns.histplot(x='SV',data=df,kde=True)

plt.subplot(1,3,2)
sns.regplot(x='SV',y='W',data=df)

plt.subplot(1,3,3)
sns.boxplot(y='SV',data=df)

plt.show()

# %%
# Win and Complete Games(SV)

plt.figure(figsize=(20,5))
plt.subplot(1,3,1)
sns.histplot(x='SV',data=df,kde=True)

plt.subplot(1,3,2)
sns.regplot(x='SV',y='W',data=df)

plt.subplot(1,3,3)
sns.boxplot(y='SV',data=df)

plt.show()

# %%
# Win and Errors(E)

plt.figure(figsize=(20,5))
plt.subplot(1,3,1)
sns.histplot(x='E',data=df,kde=True)

plt.subplot(1,3,2)
sns.regplot(x='E',y='W',data=df)

plt.subplot(1,3,3)
sns.boxplot(y='E',data=df)

plt.show()

# %%
plt.figure(figsize=(12,6))
sns.heatmap(df.corr(),cmap='coolwarm',annot=True)
# Out:
# <AxesSubplot:>

# %%
y = df.iloc[:, 1]
X = df

# Label Encoding 
from sklearn.preprocessing import LabelEncoder
lb = LabelEncoder()
y = lb.fit_transform(y)

# %%
# Splitting data to training and testing  
from sklearn.model_selection import train_test_split
x_train_scaler, x_test_scaler, x_train_scaler, y_test = train_test_split(X, y, test_size = 0.25, random_state = 40)
